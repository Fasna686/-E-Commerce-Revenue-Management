# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ECom_Data=pd.read_csv("E-Commerce.csv")
ECom_Data
# Out:
#                       Customer_uniq_id Region  Order_Date  \
# 0     e71017e224688489edfe856f2308806d  East   24-10-2021
# 1     6286847ee2da18f587503db49511c539  East   24-10-2021
# 2     0686fec9b70e5039583a38119ca0c835   West  24-10-2021
# 3     ea2406dc597bee2abb6b867fa668501f   West  24-10-2021
# 4     5935ed077915347dc695744df68c565c  East   03-09-2021
# ...                                ...    ...         ...
# 8901  90d30478255e23621e8929ed15c2f6e4  South  01-12-2020
# 8902  20a73e3f41490a73ceeba5f17658db8f   West  01-12-2020
# 8903  5c1554cd45f9d538c2c6947dbdd59c75  East   01-12-2020
# 8904  6b737a4deca1ed0e56c179e66036e994   West  01-12-2020
# 8905  a5235ac28d3d5487f54025f9d6b57433  North  01-12-2020
#
#      Expected_Delivery_Date Delivered_Date  \
# 0                25-10-2021     25-10-2021
# 1                25-10-2021     25-10-2021
# 2                25-10-2021     25-10-2021
# 3                25-10-2021     25-10-2021
# 4                04-09-2021     04-09-2021
# ...

# %% [markdown]
# ###  Q1-a) Print out the first 10 and the last 10 records of the data. (2 marks) b) How many rows and columns are present in the dataset? Use any two different methods to extract this information. (2 + 2 + 2 marks) c) How many object data types are there? (1 mark) d) Is there any Boolean data type?

# %%
#1-a)-A
#Print out the first 10 and the last 10 records of the data
ECom_Data.head(10)
# Out:
#                    Customer_uniq_id Region  Order_Date Expected_Delivery_Date  \
# 0  e71017e224688489edfe856f2308806d  East   24-10-2021             25-10-2021
# 1  6286847ee2da18f587503db49511c539  East   24-10-2021             25-10-2021
# 2  0686fec9b70e5039583a38119ca0c835   West  24-10-2021             25-10-2021
# 3  ea2406dc597bee2abb6b867fa668501f   West  24-10-2021             25-10-2021
# 4  5935ed077915347dc695744df68c565c  East   03-09-2021             04-09-2021
# 5  89fcdddaad50084e395d0928a7426afe  East   03-09-2021             04-09-2021
# 6  b9b183aa18d3a721d2ac23e7184525b0  East   03-09-2021             04-09-2021
# 7  dee64864c0419bec80fbbb94d19bc40d  East   03-09-2021             04-09-2021
# 8  595f55f2c1293f07ea9ec9fa2bb39f46  East   03-09-2021             04-09-2021
# 9  547b6585272473ae006bcfbdb47b6ae0   West  26-08-2021             27-08-2021
#
#   Delivered_Date                                       product_name  \
# ...

# %%
#1-a)_B
ECom_Data.tail(10)
# Out:
#                       Customer_uniq_id Region  Order_Date  \
# 8896  4db03bc4ccbe216cf151b2f2b904ba3f  East   01-12-2020
# 8897  4d4d6aeb13fa253499d0dd45a5abd87e   West  01-12-2020
# 8898  ea19e7ef703293d3f6c799ca9db4642d   West  01-12-2020
# 8899  19a53a958992fb575acffb5d41e7ef9e  East   01-12-2020
# 8900  09abab80c8dfdc6f268e0a6f05a0be11  North  01-12-2020
# 8901  90d30478255e23621e8929ed15c2f6e4  South  01-12-2020
# 8902  20a73e3f41490a73ceeba5f17658db8f   West  01-12-2020
# 8903  5c1554cd45f9d538c2c6947dbdd59c75  East   01-12-2020
# 8904  6b737a4deca1ed0e56c179e66036e994   West  01-12-2020
# 8905  a5235ac28d3d5487f54025f9d6b57433  North  01-12-2020
#
#      Expected_Delivery_Date Delivered_Date  \
# 8896             04-12-2020     04-12-2020
# 8897             04-12-2020     04-12-2020
# 8898             04-12-2020     04-12-2020
# 8899             04-12-2020     04-12-2020
# 8900             04-12-2020     04-12-2020
# 8901             04-12-2020     04-12-2020
# ...

# %% [markdown]
# #1-b) How many rows and columns are present in the dataset? Use any two different methods to extract this information.
#     1-b)-A)Using shape function
#          B)Using len function

# %%
#1-b)-A
print("Number of columns=%d \nNumber of rows=%d"%(ECom_Data.shape[1],ECom_Data.shape[0]))
# Out:
# Number of columns=17
# Number of rows=8906

# %%
#1-b)-B
print("Number of rows =",len(ECom_Data))
print("Number of columns=",len(ECom_Data.columns))
# Out:
# Number of rows = 8906
# Number of columns= 17

# %% [markdown]
# #1-c) How many object data types are there? (1 mark)

# %%
#1.c
ECom_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8906 entries, 0 to 8905
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Customer_uniq_id            8906 non-null   object
#  1   Region                      8906 non-null   object
#  2   Order_Date                  8906 non-null   object
#  3   Expected_Delivery_Date      8906 non-null   object
#  4   Delivered_Date              8906 non-null   object
#  5   product_name                8906 non-null   object
#  6   product_main_category       8906 non-null   object
#  7   product_subcategory         8906 non-null   object
#  8   product_category_filter     8906 non-null   object
#  9   product_category_subfilter  8906 non-null   object
#  10  product_unique ID           8906 non-null   object
#  11  retail_price                8906 non-null   int64
#  12  discounted_price            8906 non-null   int64
# ...

# %% [markdown]
# #1-d) Is there any Boolean data type? (1 mark)

# %%
#1.d)
ECom_Data.info()
# There are no boolean type data as per info received
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8906 entries, 0 to 8905
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Customer_uniq_id            8906 non-null   object
#  1   Region                      8906 non-null   object
#  2   Order_Date                  8906 non-null   object
#  3   Expected_Delivery_Date      8906 non-null   object
#  4   Delivered_Date              8906 non-null   object
#  5   product_name                8906 non-null   object
#  6   product_main_category       8906 non-null   object
#  7   product_subcategory         8906 non-null   object
#  8   product_category_filter     8906 non-null   object
#  9   product_category_subfilter  8906 non-null   object
#  10  product_unique ID           8906 non-null   object
#  11  retail_price                8906 non-null   int64
#  12  discounted_price            8906 non-null   int64
# ...

# %% [markdown]
# ### Q 2. Eliminating the non-informative columns. a) Drop the columns product_specifications and description. (2 marks) b) Which method or function is used to permanently delete the columns mentioned in part (a)? Write the code explicitly (2 marks)

# %% [markdown]
# #2-a) Drop the columns product_specifications and description.

# %%
#2-a)
ECom_Data.drop(["product_specifications","description"],axis=1)
# Out:
#                       Customer_uniq_id Region  Order_Date  \
# 0     e71017e224688489edfe856f2308806d  East   24-10-2021
# 1     6286847ee2da18f587503db49511c539  East   24-10-2021
# 2     0686fec9b70e5039583a38119ca0c835   West  24-10-2021
# 3     ea2406dc597bee2abb6b867fa668501f   West  24-10-2021
# 4     5935ed077915347dc695744df68c565c  East   03-09-2021
# ...                                ...    ...         ...
# 8901  90d30478255e23621e8929ed15c2f6e4  South  01-12-2020
# 8902  20a73e3f41490a73ceeba5f17658db8f   West  01-12-2020
# 8903  5c1554cd45f9d538c2c6947dbdd59c75  East   01-12-2020
# 8904  6b737a4deca1ed0e56c179e66036e994   West  01-12-2020
# 8905  a5235ac28d3d5487f54025f9d6b57433  North  01-12-2020
#
#      Expected_Delivery_Date Delivered_Date  \
# 0                25-10-2021     25-10-2021
# 1                25-10-2021     25-10-2021
# 2                25-10-2021     25-10-2021
# 3                25-10-2021     25-10-2021
# 4                04-09-2021     04-09-2021
# ...

# %% [markdown]
# #2-b) Which method or function is used to permanently delete the columns mentioned in part (a)? Write the code explicitly (2 marks)¶

# %%
#2-b)
ECom_Data.drop(["product_specifications","description"],axis=1,inplace=True)
ECom_Data
# Out:
#                       Customer_uniq_id Region  Order_Date  \
# 0     e71017e224688489edfe856f2308806d  East   24-10-2021
# 1     6286847ee2da18f587503db49511c539  East   24-10-2021
# 2     0686fec9b70e5039583a38119ca0c835   West  24-10-2021
# 3     ea2406dc597bee2abb6b867fa668501f   West  24-10-2021
# 4     5935ed077915347dc695744df68c565c  East   03-09-2021
# ...                                ...    ...         ...
# 8901  90d30478255e23621e8929ed15c2f6e4  South  01-12-2020
# 8902  20a73e3f41490a73ceeba5f17658db8f   West  01-12-2020
# 8903  5c1554cd45f9d538c2c6947dbdd59c75  East   01-12-2020
# 8904  6b737a4deca1ed0e56c179e66036e994   West  01-12-2020
# 8905  a5235ac28d3d5487f54025f9d6b57433  North  01-12-2020
#
#      Expected_Delivery_Date Delivered_Date  \
# 0                25-10-2021     25-10-2021
# 1                25-10-2021     25-10-2021
# 2                25-10-2021     25-10-2021
# 3                25-10-2021     25-10-2021
# 4                04-09-2021     04-09-2021
# ...

# %% [markdown]
# ### Q 3. Here we summarize the data at brand level. a) How many unique Brand are there. (2 marks) b) Note that each Brand contains multiple products. Show the average product_rating within each Brand (2 marks)

# %% [markdown]
# #3-a) How many unique Brand are there.

# %%
ECom_Data.Brand.nunique()
# Out:
# 2484

# %% [markdown]
# #3-b) Note that each Brand contains multiple products. Show the average product_rating within each Brand (2 marks)

# %%
ECom_Data.product_main_category.unique()
ECom_Data.groupby(['Brand'])['product_rating'].mean()
# Out:
# Brand
# 1OAK           1.500000
# 3A AUTOCARE    3.268293
# 3D MAT         3.000000
# 3KFACTORY      2.000000
# 4D             3.600000
#                  ...
# ZORDEN         4.000000
# ZOSIGN         3.400000
# ZRESTHA        1.000000
# ZYXEL          3.333333
#  TARKAN        5.000000
# Name: product_rating, Length: 2484, dtype: float64

# %% [markdown]
# ### Q 4. Next we study the main categories of the products. a) Create an appropriate plot to show the count of items ordered for each product_main_category. (6 marks). Hint: Create a bar chart titled "Product Category type" where product_main_category are on x-axis and counts are on y-axis. Note: Both axis labels, i.e. the names of the product_main_category and counts must be clearly legible. b) From the plot identify for which two product_main_category(s) maximum and minimum orders were placed. (2 marks) c) Write code to print out the top 5 product_main_category(s) in descending order? (3 marks¶

# %% [markdown]
# #4-a) Create an appropriate plot to show the count of items ordered for each product_main_category.Hint: Create a bar chart titled "Product Category type" where product_main_category are on x-axis and counts are on y-axis. Note: Both axis labels, i.e. the names of the product_main_category and counts must be clearly legible

# %%
#4-a
plt.figure(figsize=(10,7,))
plt.title("Product Category type")
sns.countplot(data=ECom_Data,x="product_main_category")
plt.xlabel("product_main_category")
plt.ylabel("count")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #4-b) From the plot identify for which two product_main_category(s) maximum and minimum orders were placed.

# %%
#4-b
plt.figure(figsize=(10,7,))
plt.title("Product Category type")
sns.countplot(data=ECom_Data,x="product_main_category",order=ECom_Data["product_main_category"].value_counts().index)
plt.xlabel("product_main_category")
plt.ylabel("count")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #4- c) Write code to print out the top 5 product_main_category(s) in descending order?

# %%
#4-c
ECom_Data["product_main_category"].value_counts()
# Out:
# Clothing                       2943
# Mobiles & Accessories          1084
# Automotive                     1001
# Home Decor & Festive Needs      727
# Computers                       558
#                                ...
# Pet Supplies                     20
# Home Entertainment               17
# Household Supplies                4
# Food & Nutrition                  2
# Wearable Smart Devices            1
# Name: product_main_category, Length: 26, dtype: int64

# %% [markdown]
# ### Q 5. Find the total Revenue generated by the E-Commerce company over all orders placed. Hint: Calculate revenue of E-commerce company using the conditions mentioned above and then do the total (sum) of all to get total revenue.

# %% [markdown]
# In Q 5, find the total Revenue generated by the E-Commerce company over all orders placed.
# Use if elif condition and apply it on discounted price column.
#
# TotalRevenue = total Commission charged by the ecommercecompany basis the conditions given in the problem statement. Calculate revenue of E-commerce company using the conditions mentioned above Question 5 and then do the total (sum) of all.

# %% [markdown]
# In E-commerce, both the retailers (here brands) and the company have to make profit to sustain in the business. The E-Commerce company has the following rule for computing their own revenue:
#
# The company charges (i) 25% on the orders having final price (discounted price) greater than 600 (ii) 15% on the orders having final price (discounted price) greater than 350 but less than or equal to 600 (iii) 10% on the orders having final price (discounted price) greater than 100 but less than or equal to 350 (iv) Otherwise, 5% on the final price (discounted price) ¶

# %%
#5
def revenue(discounted_price):
    if discounted_price>600:
        return (discounted_price*0.25)
    elif discounted_price>350 and discounted_price<=600:
        return (discounted_price*0.15)
    elif discounted_price>100 and discounted_price<=350:
        return (discounted_price*0.10)
    else:
        return (discounted_price*0.05)
ECom_Data['ECom_Revenue']= ECom_Data['discounted_price'].apply(revenue)
print('The total revenue of the E-Commerce Company is:',ECom_Data['ECom_Revenue'].sum())
# Out:
# The total revenue of the E-Commerce Company is: 2217486.85

# %% [markdown]
# ### Q6.Calculate the total BrandRevenue and list the top 10 Brand having maximum revenue in descending order (6 marks) Hint: Total BrandRevenue is BrandRevenue which is generated after all the deductions. Also, BrandRevenue is different from the E-Commerce company's revenue. Brand Revenue is the discounted price minus the Revenue (generated using the conditions given above Q5)

# %% [markdown]
# The company charges (i) 25% on the orders having final price (discounted price) greater than 600 (ii) 15% on the orders having final price (discounted price) greater than 350 but less than or equal to 600 (iii) 10% on the orders having final price (discounted price) greater than 100 but less than or equal to 350 (iv) Otherwise, 5% on the final price (discounted price) ¶

# %%
#6
ECom_Data["Brand_revenue"]=ECom_Data["discounted_price"]-ECom_Data["ECom_Revenue"]
print("total Brand revenue:",ECom_Data["Brand_revenue"].sum())

ECom_Data.sort_values(by="Brand_revenue",ascending=False).head(10)
# Out:
# total Brand revenue: 7522992.15
#                       Customer_uniq_id Region  Order_Date  \
# 3650  c4b045288524a8770c760ed2bbca2ed5  South  11-03-2021
# 686   bd59f01525ff2fd65f81e0d6e8eb714e  North  04-01-2021
# 4566  a1fb13ead0d648acd61e600531421a34   West  12-03-2021
# 8215  7d7d32c337cff8f3010c162a971b7f94  East   28-03-2021
# 4567  6bdbfcd8a37c9302fea53891aaad7426  East   12-03-2021
# 708   14541dd2c572103ba7a8f1b6a45a9917  East   01-01-2021
# 3141  b1b2c798ff157a8970540bbadb49ec22   West  01-12-2020
# 3849  ae0e2b3720dcecbb1fc244c9d3e036f8  East   07-01-2021
# 8082  87065e889687f0c7a681950565c5c216   West  04-01-2021
# 3864  2c0883796495383eb6da761c27dff435  North  07-01-2021
#
#      Expected_Delivery_Date Delivered_Date  \
# 3650             14-03-2021     14-03-2021
# 686              07-01-2021     07-01-2021
# 4566             15-03-2021     15-03-2021
# 8215             31-03-2021     31-03-2021
# 4567             15-03-2021     15-03-2021
# ...

# %% [markdown]
# ## Q 7. Compare prices for each product. a) Draw boxplots of retail_price & discounted_price. (3 marks) b) Are there any outliers? (Yes/No) (1mark) c) Create a scatterplot of retail_price (x-axis) and discounted_price (y-axis) (3 marks)¶

# %% [markdown]
# ### 7-a) Draw boxplots of retail_price & discounted_price.

# %%
#7-a
plt.figure(figsize=(10,7))
sns.boxplot(data=ECom_Data,x="retail_price",orient="h")
plt.xlabel("retail_price")
plt.show()

plt.figure(figsize=(10,7))
sns.boxplot(data=ECom_Data,x="discounted_price",orient="h")
plt.xlabel("discounted_price")
plt.show()

# %% [markdown]
# ### 7-b) yes there are outliers

# %% [markdown]
# yes

# %% [markdown]
# ### 7 c) Create a scatterplot of retail_price (x-axis) and discounted_price (y-axis)

# %%
#7-b
plt.figure(figsize=(12,7))
sns.scatterplot(data=ECom_Data,x="retail_price",y="discounted_price")
plt.xlabel("ratail_price")
plt.ylabel("discounted_price")
plt.show()

# %% [markdown]
# ### Q 8. Create a new dataframe to include the Brand specific information as stated: i. total number of orders placed per Brand ii. total retail_price per Brand iii. total discounted_price per Brand, and iv. total BrandRevenue generated per Brand. Also, draw a pairplot using these four features. (6 marks)

# %%
#8
brand_summary = ECom_Data.groupby('Brand').agg({'Brand': 'count',
    'retail_price': 'sum',
    'discounted_price': 'sum',
    'Brand_revenue': 'sum'
})

df=pd.DataFrame(brand_summary)
df.rename(columns={"Brand":"order","retail_price":"total_retail","discounted_price":"total_discount","Brand_revenue":"total_brand_revenue"},inplace=True)
df
# Out:
#              order  total_retail  total_discount  total_brand_revenue
# Brand
# 1OAK             2          1698            1274              1015.40
# 3A AUTOCARE     41        107059           74134             55647.90
# 3D MAT           1          7250            6999              5249.25
# 3KFACTORY        1           399             174               156.60
# 4D               5         17500            7948              5961.00
# ...            ...           ...             ...                  ...
# ZORDEN           1          3999            2799              2099.25
# ZOSIGN           5          6995            6995              5246.25
# ZRESTHA          1          1999             899               674.25
# ZYXEL            9         64742           35392             26544.00
#  TARKAN          1          1999             349               314.10
#
# [2484 rows x 4 columns]

# %%
sns.pairplot(data=df[['order','total_retail','total_discount','total_brand_revenue']]);
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Q 9.Compare performance regionwise a) Draw a lineplot for the monthly Revenue of E-Commerce Company for each region separately. (4 marks) b) Identify the best and the worst performing months for each region. (2 marks) Note: Only those days with actual orders(Order_Date) placed are present in the dataset. Assuming there were no orders on other days. Also, show Month and Year on x-axis.

# %% [markdown]
# ####  a) Draw a lineplot for the monthly Revenue of E-Commerce Company for each region separately.

# %%
#9-a
ECom_Data_d=ECom_Data.copy()
ECom_Data_d["Order_Date"]=pd.to_datetime(ECom_Data["Order_Date"],dayfirst=True)
ECom_Data_d
ECom_Data_d["Order_Date"].dt.month
# Out:
# 0       10
# 1       10
# 2       10
# 3       10
# 4        9
#         ..
# 8901    12
# 8902    12
# 8903    12
# 8904    12
# 8905    12
# Name: Order_Date, Length: 8906, dtype: int64

# %%
plt.figure(figsize = (10,7))
sns.lineplot(data = ECom_Data_d, x = 'Order_Date' , y = 'ECom_Revenue',hue='Region',errorbar=('ci', False))
plt.ylabel('Ecom Revenue')
plt.xlabel('Order placed range')
plt.show();

# %% [markdown]
# ###  b) Identify the best and the worst performing months for each region.

# %%
#9b 
#East (Best Month- April, Worst Month- October- almost 0 sales)
#West (Best Month- March, Worst Month-February flat sales )
#North (Best Month- December, Worst Month- February)
#South (Best Month- March, Worst Month- July)
